# %% [markdown]
# <a href="https://colab.research.google.com/github/lorenzrossi/AMD-ComicsFaces/blob/main/AMD_Models_droput_batch_2Dense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from os import listdir
import pandas as pd
# Basic packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import pickle

# Image preprocessing
import pathlib
import PIL
import PIL.Image
import cv2

# Neural Networks
import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical, load_img, img_to_array
from keras.wrappers.scikit_learn import KerasClassifier
from keras.preprocessing.image import ImageDataGenerator
from keras import models, layers, callbacks, regularizers
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout, Activation
from keras.optimizers import Adam, SGD, RMSprop
from keras.losses import binary_crossentropy
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# Cross Validation
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score, zero_one_loss

tfk = tf.keras
tf.keras.backend.set_floatx("float64")


from google.colab import drive
drive.mount('/content/drive')

dir = '/content/drive/MyDrive/ComicsFaces'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X = pickle.load(open('/content/drive/MyDrive/ComicsFaces/Pickles/X.pickle','rb'))
y = pickle.load(open('/content/drive/MyDrive/ComicsFaces/Pickles/y.pickle','rb'))

pics_classes = ['comics','faces']

images_to_plot = 6

# %%
f, ax = plt.subplots(1, images_to_plot)
f.set_size_inches(30, 20)

gray_channel = 0

for i in range(images_to_plot):
  gray_image = X[i][:, :, gray_channel]
  ax[i].imshow(gray_image, cmap = "gray")
  numeric_label = y[i]
  ax[i].set_title(pics_classes[numeric_label])

# %%
number_of_classes = len(pics_classes)

# %%
x_size, img_dim = X.shape[0], X.shape[1]

# rescale in [0,1]
X = tf.cast(X, tf.float32) / 255.0

# one hot encoding
depth = 1
y = tf.reshape(tf.one_hot(y, depth), shape = [x_size, depth])

# %%
# Train test splitting
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
# Hyperparameters
epoch = 25 # n of epochs
batch = 64 # batch size

# Defining the loss
loss = keras.losses.BinaryCrossentropy()

# Defining the optimizer(s)
op_1 = Adam()
#op_2 = SGD(learning_rate=0.01, momentum=0.9, decay=0.01/25)

# %%
# Defining plots
legend_size = 14

def performance_plot(history):
    plt.figure(figsize=(20,8))

    # Loss plots
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('loss', size = 12)
    plt.xlabel('epoch', size = 12)
    plt.legend(['train','test'], fontsize = legend_size)

    # Accuracy plots
    plt.subplot(1,2,2)
    plt.plot(history.history['binary_accuracy'])
    plt.plot(history.history['val_binary_accuracy'])
    plt.ylabel('accuracy', size = 12)
    plt.xlabel('epoch', size = 12)
    plt.legend(['train','val'], fontsize = legend_size)

    plt.show()

# %% [markdown]
# # TRAINING MODEL 1

# %%
model1 = tf.keras.Sequential([
        layers.Conv2D(32, (3, 3), padding = "same", use_bias=False, input_shape = (100, 100, 1), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), padding = "same", use_bias=False, activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size = (2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(256, use_bias=False, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.25),
        layers.Dense(128, use_bias=False, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(1, activation = 'sigmoid')
        ])
model1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 100, 100, 32)      288
#
#  batch_normalization_15 (Bat  (None, 100, 100, 32)     128
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 100, 100, 32)      9216
#
#  batch_normalization_16 (Bat  (None, 100, 100, 32)     128
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 50, 50, 32)        0
#
#  flatten_3 (Flatten)         (None, 80000)             0
#
#  dense_9 (Dense)             (None, 256)               20480000
#
#  batch_normalization_17 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32768
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 20,524,193
# Trainable params: 20,523,297
# Non-trainable params: 896
# _________________________________________________________________

# %%
keras.utils.plot_model(model1, 'model.png')

# %%
# compiling the model
model1.compile(optimizer = op_1, loss=loss, metrics=['binary_accuracy'])

history = model1.fit(X_train, y_train, epochs = epoch, batch_size = batch, verbose = 1, validation_split = 0.2)

performance_plot(history)

result_1 = model1.evaluate(X_test, y_test)
print("test loss, test acc:", result_1)
# Out:
# Epoch 1/25
# 200/200 [==============================] - 9s 36ms/step - loss: 0.0234 - binary_accuracy: 0.9916 - val_loss: 3.3004 - val_binary_accuracy: 0.4791
# Epoch 2/25
# 200/200 [==============================] - 7s 35ms/step - loss: 0.0041 - binary_accuracy: 0.9990 - val_loss: 1.0778 - val_binary_accuracy: 0.8231
# Epoch 3/25
# 200/200 [==============================] - 7s 35ms/step - loss: 0.0019 - binary_accuracy: 0.9995 - val_loss: 0.0353 - val_binary_accuracy: 0.9897
# Epoch 4/25
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2979e-04 - binary_accuracy: 0.9998 - val_loss: 0.0027 - val_binary_accuracy: 0.9994
# Epoch 5/25
# 200/200 [==============================] - 7s 35ms/step - loss: 2.4717e-04 - binary_accuracy: 1.0000 - val_loss: 0.0031 - val_binary_accuracy: 0.9997
# Epoch 6/25
# 200/200 [==============================] - 7s 34ms/step - loss: 1.3631e-04 - binary_accuracy: 1.0000 - val_loss: 0.0029 - val_binary_accuracy: 0.9997
# Epoch 7/25
# 200/200 [==============================] - 7s 34ms/step - loss: 1.1006e-04 - binary_accuracy: 1.0000 - val_loss: 0.0030 - val_binary_accuracy: 0.9997
# Epoch 8/25
# 200/200 [==============================] - 7s 34ms/step - loss: 1.7835e-04 - binary_accuracy: 1.0000 - val_loss: 0.0171 - val_binary_accuracy: 0.9972
# Epoch 9/25
# 200/200 [==============================] - 7s 34ms/step - loss: 0.0039 - binary_accuracy: 0.9987 - val_loss: 0.0145 - val_binary_accuracy: 0.9978
# Epoch 10/25
# 200/200 [==============================] - 7s 34ms/step - loss: 0.0037 - binary_accuracy: 0.9991 - val_loss: 0.0161 - val_binary_accuracy: 0.9956
# Epoch 11/25
# 200/200 [==============================] - 7s 34ms/step - loss: 9.5171e-04 - binary_accuracy: 0.9998 - val_loss: 0.0021 - val_binary_accuracy: 0.9994
# Epoch 12/25
# 200/200 [==============================] - 7s 34ms/step - loss: 0.0017 - binary_accuracy: 0.9995 - val_loss: 0.0034 - val_binary_accuracy: 0.9988
# Epoch 13/25
# 200/200 [==============================] - 7s 34ms/step - loss: 1.2148e-04 - binary_accuracy: 1.0000 - val_loss: 0.0032 - val_binary_accuracy: 0.9997
# Epoch 14/25
# 200/200 [==============================] - 7s 34ms/step - loss: 1.0676e-04 - binary_accuracy: 1.0000 - val_loss: 0.0034 - val_binary_accuracy: 0.9997
# Epoch 15/25
# 200/200 [==============================] - 7s 34ms/step - loss: 1.0574e-04 - binary_accuracy: 1.0000 - val_loss: 0.0046 - val_binary_accuracy: 0.9994
# Epoch 16/25
# 200/200 [==============================] - 7s 34ms/step - loss: 8.6504e-05 - binary_accuracy: 1.0000 - val_loss: 0.3259 - val_binary_accuracy: 0.9531
# Epoch 17/25
# 200/200 [==============================] - 7s 35ms/step - loss: 1.0355e-04 - binary_accuracy: 1.0000 - val_loss: 0.0039 - val_binary_accuracy: 0.9997
# Epoch 18/25
# 200/200 [==============================] - 7s 35ms/step - loss: 4.5763e-05 - binary_accuracy: 1.0000 - val_loss: 0.0042 - val_binary_accuracy: 0.9997
# Epoch 19/25
# 200/200 [==============================] - 7s 35ms/step - loss: 2.0029e-05 - binary_accuracy: 1.0000 - val_loss: 0.0044 - val_binary_accuracy: 0.9997
# Epoch 20/25
# 200/200 [==============================] - 7s 35ms/step - loss: 1.7886e-05 - binary_accuracy: 1.0000 - val_loss: 0.0044 - val_binary_accuracy: 0.9997
# Epoch 21/25
# 200/200 [==============================] - 7s 35ms/step - loss: 0.0035 - binary_accuracy: 0.9993 - val_loss: 2.4068 - val_binary_accuracy: 0.6259
# Epoch 22/25
# 200/200 [==============================] - 7s 35ms/step - loss: 0.0017 - binary_accuracy: 0.9995 - val_loss: 0.1191 - val_binary_accuracy: 0.9619
# Epoch 23/25
# 200/200 [==============================] - 7s 35ms/step - loss: 0.0012 - binary_accuracy: 0.9997 - val_loss: 0.0252 - val_binary_accuracy: 0.9947
# Epoch 24/25
# 200/200 [==============================] - 7s 35ms/step - loss: 5.6231e-04 - binary_accuracy: 0.9998 - val_loss: 0.0165 - val_binary_accuracy: 0.9962
# Epoch 25/25
# 200/200 [==============================] - 7s 35ms/step - loss: 2.8090e-04 - binary_accuracy: 0.9998 - val_loss: 0.0052 - val_binary_accuracy: 0.9997
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0031 - binary_accuracy: 0.9995
# test loss, test acc: [0.003123568613127692, 0.9995]

# %% [markdown]
# # TRAINING MODEL 2

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), padding = "same", use_bias=False, input_shape = (100, 100, 1), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3, 3), padding = "same", use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 100, 100, 32)      288
#
#  batch_normalization_19 (Bat  (None, 100, 100, 32)     128
#  chNormalization)
#
#  conv2d_12 (Conv2D)          (None, 100, 100, 32)      9216
#
#  batch_normalization_20 (Bat  (None, 100, 100, 32)     128
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  dropout_15 (Dropout)        (None, 50, 50, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 50, 50, 64)        18432
#
#  batch_normalization_21 (Bat  (None, 50, 50, 64)       256
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  dropout_16 (Dropout)        (None, 25, 25, 64)        0
#
#  flatten_4 (Flatten)         (None, 40000)             0
#
#  dense_12 (Dense)            (None, 256)               10240000
#
#  batch_normalization_22 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32768
#
#  batch_normalization_23 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 10,302,881
# Trainable params: 10,301,857
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# compiling the model
model2.compile(optimizer = op_1, loss=loss, metrics=['binary_accuracy'])

history = model2.fit(X_train, y_train, epochs = epoch, batch_size = batch, verbose = 1, validation_split = 0.2)

performance_plot(history)

result_2 = model2.evaluate(X_test, y_test)
print("test loss, test acc:", result_2)
# Out:
# Epoch 1/25
# 200/200 [==============================] - 10s 43ms/step - loss: 0.0240 - binary_accuracy: 0.9915 - val_loss: 6.8297 - val_binary_accuracy: 0.5209
# Epoch 2/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0042 - binary_accuracy: 0.9985 - val_loss: 8.6231 - val_binary_accuracy: 0.5209
# Epoch 3/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0032 - binary_accuracy: 0.9991 - val_loss: 0.1829 - val_binary_accuracy: 0.9278
# Epoch 4/25
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0032 - binary_accuracy: 0.9989 - val_loss: 0.0166 - val_binary_accuracy: 0.9978
# Epoch 5/25
# 200/200 [==============================] - 8s 42ms/step - loss: 8.1608e-04 - binary_accuracy: 0.9998 - val_loss: 0.0286 - val_binary_accuracy: 0.9969
# Epoch 6/25
# 200/200 [==============================] - 8s 42ms/step - loss: 6.7841e-04 - binary_accuracy: 0.9998 - val_loss: 0.0029 - val_binary_accuracy: 0.9994
# Epoch 7/25
# 200/200 [==============================] - 8s 42ms/step - loss: 9.6237e-04 - binary_accuracy: 0.9998 - val_loss: 0.1232 - val_binary_accuracy: 0.9928
# Epoch 8/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0042 - binary_accuracy: 0.9988 - val_loss: 0.0067 - val_binary_accuracy: 0.9981
# Epoch 9/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0026 - binary_accuracy: 0.9992 - val_loss: 0.0015 - val_binary_accuracy: 0.9997
# Epoch 10/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0015 - binary_accuracy: 0.9994 - val_loss: 0.0202 - val_binary_accuracy: 0.9978
# Epoch 11/25
# 200/200 [==============================] - 8s 42ms/step - loss: 6.9295e-04 - binary_accuracy: 0.9998 - val_loss: 0.0114 - val_binary_accuracy: 0.9984
# Epoch 12/25
# 200/200 [==============================] - 8s 42ms/step - loss: 1.7023e-04 - binary_accuracy: 1.0000 - val_loss: 0.0040 - val_binary_accuracy: 0.9991
# Epoch 13/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0012 - binary_accuracy: 0.9995 - val_loss: 0.0112 - val_binary_accuracy: 0.9984
# Epoch 14/25
# 200/200 [==============================] - 8s 42ms/step - loss: 2.7762e-04 - binary_accuracy: 0.9998 - val_loss: 0.0257 - val_binary_accuracy: 0.9981
# Epoch 15/25
# 200/200 [==============================] - 8s 42ms/step - loss: 1.3272e-04 - binary_accuracy: 1.0000 - val_loss: 0.0186 - val_binary_accuracy: 0.9988
# Epoch 16/25
# 200/200 [==============================] - 8s 42ms/step - loss: 4.4530e-04 - binary_accuracy: 0.9998 - val_loss: 0.0540 - val_binary_accuracy: 0.9975
# Epoch 17/25
# 200/200 [==============================] - 8s 42ms/step - loss: 1.8459e-04 - binary_accuracy: 0.9999 - val_loss: 0.0050 - val_binary_accuracy: 0.9994
# Epoch 18/25
# 200/200 [==============================] - 8s 42ms/step - loss: 1.6652e-04 - binary_accuracy: 1.0000 - val_loss: 0.0039 - val_binary_accuracy: 0.9997
# Epoch 19/25
# 200/200 [==============================] - 8s 42ms/step - loss: 4.4779e-04 - binary_accuracy: 0.9998 - val_loss: 3.3134 - val_binary_accuracy: 0.5778
# Epoch 20/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0018 - binary_accuracy: 0.9992 - val_loss: 0.0247 - val_binary_accuracy: 0.9941
# Epoch 21/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0019 - binary_accuracy: 0.9995 - val_loss: 0.0075 - val_binary_accuracy: 0.9981
# Epoch 22/25
# 200/200 [==============================] - 8s 42ms/step - loss: 4.8128e-04 - binary_accuracy: 0.9999 - val_loss: 0.1157 - val_binary_accuracy: 0.9819
# Epoch 23/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0014 - binary_accuracy: 0.9994 - val_loss: 0.3273 - val_binary_accuracy: 0.9784
# Epoch 24/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0012 - binary_accuracy: 0.9996 - val_loss: 0.0042 - val_binary_accuracy: 0.9994
# Epoch 25/25
# 200/200 [==============================] - 8s 42ms/step - loss: 0.0013 - binary_accuracy: 0.9998 - val_loss: 0.0044 - val_binary_accuracy: 0.9997
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - binary_accuracy: 0.9992
# test loss, test acc: [0.002946775056576027, 0.99925]

# %% [markdown]
# # TRAINING MODEL 3

# %%
model3 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), padding = "same", use_bias=False, input_shape = (100, 100, 1), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3, 3), padding = "same", use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(128, (3, 3), padding = "same", use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, use_bias=False, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])
model3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 100, 100, 32)      288
#
#  batch_normalization_24 (Bat  (None, 100, 100, 32)     128
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 100, 100, 32)      9216
#
#  batch_normalization_25 (Bat  (None, 100, 100, 32)     128
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  dropout_19 (Dropout)        (None, 50, 50, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 50, 50, 64)        18432
#
#  batch_normalization_26 (Bat  (None, 50, 50, 64)       256
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 25, 25, 64)       0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 25, 25, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 25, 25, 128)       73728
#
#  batch_normalization_27 (Bat  (None, 25, 25, 128)      512
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 12, 12, 128)       0
#
#  flatten_5 (Flatten)         (None, 18432)             0
#
#  dense_15 (Dense)            (None, 256)               4718592
#
#  batch_normalization_28 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32768
#
#  batch_normalization_29 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 4,855,713
# Trainable params: 4,854,433
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
# compiling the model
model3.compile(optimizer = op_1, loss=loss, metrics=['binary_accuracy'])

history = model3.fit(X_train, y_train, epochs = epoch, batch_size = batch, verbose = 1, validation_split = 0.2)

performance_plot(history)

result_3 = model3.evaluate(X_test, y_test)
print("test loss, test acc:", result_3)
# Out:
# Epoch 1/25
# 200/200 [==============================] - 11s 47ms/step - loss: 0.0261 - binary_accuracy: 0.9905 - val_loss: 6.1564 - val_binary_accuracy: 0.5209
# Epoch 2/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0080 - binary_accuracy: 0.9976 - val_loss: 1.7176 - val_binary_accuracy: 0.5238
# Epoch 3/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0040 - binary_accuracy: 0.9985 - val_loss: 0.0807 - val_binary_accuracy: 0.9728
# Epoch 4/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0022 - binary_accuracy: 0.9995 - val_loss: 0.0237 - val_binary_accuracy: 0.9912
# Epoch 5/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0024 - binary_accuracy: 0.9993 - val_loss: 0.0040 - val_binary_accuracy: 0.9994
# Epoch 6/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0025 - binary_accuracy: 0.9993 - val_loss: 0.0096 - val_binary_accuracy: 0.9975
# Epoch 7/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0034 - binary_accuracy: 0.9990 - val_loss: 0.0176 - val_binary_accuracy: 0.9941
# Epoch 8/25
# 200/200 [==============================] - 9s 46ms/step - loss: 8.3574e-04 - binary_accuracy: 0.9998 - val_loss: 0.0025 - val_binary_accuracy: 0.9997
# Epoch 9/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0010 - binary_accuracy: 0.9997 - val_loss: 0.0034 - val_binary_accuracy: 0.9997
# Epoch 10/25
# 200/200 [==============================] - 9s 46ms/step - loss: 9.5894e-04 - binary_accuracy: 0.9998 - val_loss: 0.0682 - val_binary_accuracy: 0.9781
# Epoch 11/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0034 - binary_accuracy: 0.9991 - val_loss: 0.0049 - val_binary_accuracy: 0.9994
# Epoch 12/25
# 200/200 [==============================] - 9s 46ms/step - loss: 7.6045e-04 - binary_accuracy: 0.9997 - val_loss: 0.0044 - val_binary_accuracy: 0.9994
# Epoch 13/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0017 - binary_accuracy: 0.9995 - val_loss: 0.0043 - val_binary_accuracy: 0.9997
# Epoch 14/25
# 200/200 [==============================] - 9s 46ms/step - loss: 3.4476e-04 - binary_accuracy: 0.9999 - val_loss: 0.0051 - val_binary_accuracy: 0.9994
# Epoch 15/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0034 - binary_accuracy: 0.9991 - val_loss: 0.6072 - val_binary_accuracy: 0.8662
# Epoch 16/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0035 - binary_accuracy: 0.9991 - val_loss: 0.0140 - val_binary_accuracy: 0.9959
# Epoch 17/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0013 - binary_accuracy: 0.9994 - val_loss: 0.0031 - val_binary_accuracy: 0.9988
# Epoch 18/25
# 200/200 [==============================] - 9s 46ms/step - loss: 8.9013e-04 - binary_accuracy: 0.9998 - val_loss: 0.0035 - val_binary_accuracy: 0.9994
# Epoch 19/25
# 200/200 [==============================] - 9s 46ms/step - loss: 9.6660e-04 - binary_accuracy: 0.9998 - val_loss: 0.0018 - val_binary_accuracy: 0.9994
# Epoch 20/25
# 200/200 [==============================] - 9s 46ms/step - loss: 8.3703e-04 - binary_accuracy: 0.9997 - val_loss: 0.0031 - val_binary_accuracy: 0.9994
# Epoch 21/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0016 - binary_accuracy: 0.9998 - val_loss: 0.0040 - val_binary_accuracy: 0.9997
# Epoch 22/25
# 200/200 [==============================] - 9s 46ms/step - loss: 6.1611e-05 - binary_accuracy: 1.0000 - val_loss: 0.0075 - val_binary_accuracy: 0.9994
# Epoch 23/25
# 200/200 [==============================] - 9s 46ms/step - loss: 4.6575e-04 - binary_accuracy: 0.9998 - val_loss: 0.0034 - val_binary_accuracy: 0.9997
# Epoch 24/25
# 200/200 [==============================] - 9s 46ms/step - loss: 0.0022 - binary_accuracy: 0.9993 - val_loss: 0.0042 - val_binary_accuracy: 0.9994
# Epoch 25/25
# 200/200 [==============================] - 9s 46ms/step - loss: 9.9566e-04 - binary_accuracy: 0.9996 - val_loss: 0.0036 - val_binary_accuracy: 0.9994
# 125/125 [==============================] - 1s 9ms/step - loss: 4.0503e-04 - binary_accuracy: 0.9998
# test loss, test acc: [0.0004050261068531225, 0.99975]
